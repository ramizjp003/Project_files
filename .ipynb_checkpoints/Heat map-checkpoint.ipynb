# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data(2).csv")
df.head()
# Out:
#    Compound Concentration (µM)  Novobiocin Concentration (µg/ml)  OD (600nm)
# 0                       100.00                              50.0      0.0917
# 1                        50.00                              50.0      0.0988
# 2                        25.00                              50.0      0.0986
# 3                        12.50                              50.0      0.0883
# 4                         6.25                              50.0      0.0935

# %%
df.columns = ["Compound Concentration","Novobiocin Concentration",'OD']
df.head()
# Out:
#    Compound Concentration  Novobiocin Concentration      OD
# 0                  100.00                      50.0  0.0917
# 1                   50.00                      50.0  0.0988
# 2                   25.00                      50.0  0.0986
# 3                   12.50                      50.0  0.0883
# 4                    6.25                      50.0  0.0935

# %%
pivot = df.pivot(index='Novobiocin Concentration',columns = 'Compound Concentration', values = 'OD')
ax = sns.heatmap(pivot, annot=True)
